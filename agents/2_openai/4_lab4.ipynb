# %% [markdown]
# ## Deep Research
#
# One of the classic cross-business Agentic use cases! This is huge.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">A Deep Research agent is broadly applicable to any business area, and to your own day-to-day activities. You can make use of this yourself!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
pip install openai-agents
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai-agents
#   Downloading openai_agents-0.2.11-py3-none-any.whl.metadata (12 kB)
# Collecting griffe<2,>=1.5.6 (from openai-agents)
#   Downloading griffe-1.14.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting mcp<2,>=1.11.0 (from openai-agents)
#   Downloading mcp-1.13.1-py3-none-any.whl.metadata (74 kB)
# Collecting openai<2,>=1.104.1 (from openai-agents)
#   Downloading openai-1.107.0-py3-none-any.whl.metadata (29 kB)
# Collecting pydantic<3,>=2.10 (from openai-agents)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: requests<3,>=2.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from openai-agents) (2.32.3)
# Requirement already satisfied: types-requests<3,>=2.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from openai-agents) (2.32.0.20240712)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from openai-agents) (4.12.2)
# Requirement already satisfied: colorama>=0.4 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from griffe<2,>=1.5.6->openai-agents) (0.4.6)
# Collecting anyio>=4.5 (from mcp<2,>=1.11.0->openai-agents)
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from mcp<2,>=1.11.0->openai-agents) (0.4.0)
# Collecting httpx>=0.27.1 (from mcp<2,>=1.11.0->openai-agents)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from mcp<2,>=1.11.0->openai-agents) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from mcp<2,>=1.11.0->openai-agents) (2.7.1)
# Collecting python-multipart>=0.0.9 (from mcp<2,>=1.11.0->openai-agents)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywin32>=310 (from mcp<2,>=1.11.0->openai-agents)
#   Downloading pywin32-311-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting sse-starlette>=1.6.1 (from mcp<2,>=1.11.0->openai-agents)
#   Downloading sse_starlette-3.0.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: starlette>=0.27 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from mcp<2,>=1.11.0->openai-agents) (0.41.3)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from mcp<2,>=1.11.0->openai-agents) (0.32.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from openai<2,>=1.104.1->openai-agents) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from openai<2,>=1.104.1->openai-agents) (0.5.0)
# Requirement already satisfied: sniffio in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from openai<2,>=1.104.1->openai-agents) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from openai<2,>=1.104.1->openai-agents) (4.66.5)
# Requirement already satisfied: idna>=2.8 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from anyio>=4.5->mcp<2,>=1.11.0->openai-agents) (3.8)
# Requirement already satisfied: certifi in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from pydantic<3,>=2.10->openai-agents) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=2.10->openai-agents)
#   Downloading pydantic_core-2.33.2-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=2.10->openai-agents)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from requests<3,>=2.0->openai-agents) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from requests<3,>=2.0->openai-agents) (2.2.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (0.20.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.11.0->openai-agents) (1.0.1)
# Requirement already satisfied: click>=7.0 in c:\users\vagner machado\appdata\roaming\python\python312\site-packages (from uvicorn>=0.31.1->mcp<2,>=1.11.0->openai-agents) (8.1.7)
# Downloading openai_agents-0.2.11-py3-none-any.whl (179 kB)
# Downloading griffe-1.14.0-py3-none-any.whl (144 kB)
# Downloading mcp-1.13.1-py3-none-any.whl (161 kB)
# Downloading openai-1.107.0-py3-none-any.whl (950 kB)
#    ---------------------------------------- 0.0/951.0 kB ? eta -:--:--
#    --------------------------------------- 951.0/951.0 kB 22.2 MB/s eta 0:00:00
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 9.8 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading pywin32-311-cp312-cp312-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------- -------------------------- 3.1/9.5 MB 13.2 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.5 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.5 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 11.1 MB/s eta 0:00:00
# Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: pywin32, typing-inspection, python-multipart, pydantic-core, griffe, anyio, sse-starlette, pydantic, httpx, openai, mcp, openai-agents
#
#   Attempting uninstall: pywin32
#
#     Found existing installation: pywin32 306
#
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#     Uninstalling pywin32-306:
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#       Successfully uninstalled pywin32-306
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ----------------------------------------  0/12 [pywin32]
#    ------ ---------------------------------  2/12 [python-multipart]
#   Attempting uninstall: pydantic-core
#    ------ ---------------------------------  2/12 [python-multipart]
#     Found existing installation: pydantic_core 2.23.4
#    ------ ---------------------------------  2/12 [python-multipart]
#     Uninstalling pydantic_core-2.23.4:
#    ------ ---------------------------------  2/12 [python-multipart]
#       Successfully uninstalled pydantic_core-2.23.4
#    ------ ---------------------------------  2/12 [python-multipart]
#    ---------- -----------------------------  3/12 [pydantic-core]
#    ------------- --------------------------  4/12 [griffe]
#    ------------- --------------------------  4/12 [griffe]
#    ------------- --------------------------  4/12 [griffe]
#    ------------- --------------------------  4/12 [griffe]
#    ------------- --------------------------  4/12 [griffe]
#    ------------- --------------------------  4/12 [griffe]
#   Attempting uninstall: anyio
#    ------------- --------------------------  4/12 [griffe]
#     Found existing installation: anyio 4.4.0
#    ------------- --------------------------  4/12 [griffe]
#     Uninstalling anyio-4.4.0:
#    ------------- --------------------------  4/12 [griffe]
#       Successfully uninstalled anyio-4.4.0
#    ------------- --------------------------  4/12 [griffe]
#    ---------------- -----------------------  5/12 [anyio]
#    ---------------- -----------------------  5/12 [anyio]
#    ---------------- -----------------------  5/12 [anyio]
#    ---------------- -----------------------  5/12 [anyio]
#    ---------------- -----------------------  5/12 [anyio]
#    -------------------- -------------------  6/12 [sse-starlette]
#   Attempting uninstall: pydantic
#    -------------------- -------------------  6/12 [sse-starlette]
#     Found existing installation: pydantic 2.9.2
#    -------------------- -------------------  6/12 [sse-starlette]
#    ----------------------- ----------------  7/12 [pydantic]
#     Uninstalling pydantic-2.9.2:
#    ----------------------- ----------------  7/12 [pydantic]
#       Successfully uninstalled pydantic-2.9.2
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#    ----------------------- ----------------  7/12 [pydantic]
#   Attempting uninstall: httpx
#    ----------------------- ----------------  7/12 [pydantic]
#     Found existing installation: httpx 0.27.0
#    ----------------------- ----------------  7/12 [pydantic]
#     Uninstalling httpx-0.27.0:
#    ----------------------- ----------------  7/12 [pydantic]
#       Successfully uninstalled httpx-0.27.0
#    ----------------------- ----------------  7/12 [pydantic]
#    -------------------------- -------------  8/12 [httpx]
#    -------------------------- -------------  8/12 [httpx]
#    -------------------------- -------------  8/12 [httpx]
#    -------------------------- -------------  8/12 [httpx]
#   Attempting uninstall: openai
#    -------------------------- -------------  8/12 [httpx]
#     Found existing installation: openai 1.42.0
#    -------------------------- -------------  8/12 [httpx]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#     Uninstalling openai-1.42.0:
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#       Successfully uninstalled openai-1.42.0
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    ------------------------------ ---------  9/12 [openai]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    --------------------------------- ------ 10/12 [mcp]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ------------------------------------ --- 11/12 [openai-agents]
#    ---------------------------------------- 12/12 [openai-agents]
#
# Successfully installed anyio-4.10.0 griffe-1.14.0 httpx-0.28.1 mcp-1.13.1 openai-1.107.0 openai-agents-0.2.11 pydantic-2.11.7 pydantic-core-2.33.2 python-multipart-0.0.20 pywin32-311 sse-starlette-3.0.2 typing-inspection-0.4.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unstructured-client 0.28.1 requires pydantic<2.10.0,>=2.9.2, but you have pydantic 2.11.7 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from agents import Agent, WebSearchTool, trace, Runner, gen_trace_id, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import asyncio
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
from typing import Dict
from IPython.display import display, Markdown

# %%
from agents import Agent, WebSearchTool, trace, Runner, gen_trace_id, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import asyncio
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
from typing import Dict
from IPython.display import display, Markdown

# %%
from agents import Agent, WebSearchTool, trace, Runner, gen_trace_id, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import asyncio
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
from typing import Dict
from IPython.display import display, Markdown

# %%
from agents import Agent, WebSearchTool, trace, Runner, gen_trace_id, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import asyncio
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
from typing import Dict
from IPython.display import display, Markdown

# %%
from agents import Agent, WebSearchTool, trace, Runner, gen_trace_id, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import asyncio
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
from typing import Dict
from IPython.display import display, Markdown

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## OpenAI Hosted Tools
#
# OpenAI Agents SDK includes the following hosted tools:
#
# The `WebSearchTool` lets an agent search the web.
# The `FileSearchTool` allows retrieving information from your OpenAI Vector Stores.
# The `ComputerTool` allows automating computer use tasks like taking screenshots and clicking.
#
# ### Important note - API charge of WebSearchTool
#
# This is costing me 2.5 cents per call for OpenAI WebSearchTool. That can add up to $2-$3 for the next 2 labs. We'll use low cost Search tools with other platforms, so feel free to skip running this if the cost is a concern.
#
# Costs are here: https://platform.openai.com/docs/pricing#web-search

# %%
INSTRUCTIONS = "You are a research assistant. Given a search term, you search the web for that term and \
produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 \
words. Capture the main points. Write succintly, no need to have complete sentences or good \
grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the \
essence and ignore any fluff. Do not include any additional commentary other than the summary itself."

search_agent = Agent(
    name="Search agent",
    instructions=INSTRUCTIONS,
    tools=[WebSearchTool(search_context_size="low")],
    model="gpt-4o-mini",
    model_settings=ModelSettings(tool_choice="required"),
)

# tool choice: required means the agent will have to use the tools provided to it.

# %%
message = "Latest AI Agent frameworks in 2025"

with trace("Search"):
    result = await Runner.run(search_agent, message)

display(Markdown(result.final_output))
# Out:
# In 2025, several AI agent frameworks have emerged, each offering unique features to enhance the development and deployment of intelligent agents:
#
# - **LangChain**: A versatile framework for building LLM-powered applications, LangChain addresses challenges like context retention and multi-step task execution. It offers chain and agent abstractions for workflows, integrates with multiple LLMs (OpenAI, Hugging Face), and provides tools for API interactions, semantic search, and prompt engineering. ([linkedin.com](https://www.linkedin.com/pulse/top-5-frameworks-building-ai-agents-2025-sahil-malhotra-wmisc?utm_source=openai))
#
# - **LangGraph**: An extension of LangChain, LangGraph specializes in stateful, multi-actor systems, ideal for complex workflows and adaptive AI applications. It features multi-agent coordination and planning, a graph-based representation of workflows, and advanced error handling and adaptive execution. ([linkedin.com](https://www.linkedin.com/pulse/top-5-frameworks-building-ai-agents-2025-sahil-malhotra-wmisc?utm_source=openai))
#
# - **CrewAI**: Focused on role-based AI agents, CrewAI is perfect for collaborative problem-solving environments requiring diverse expertise. It offers a role-based architecture for specialized agents, dynamic task planning and conflict resolution, and simulation engines for training and testing. ([linkedin.com](https://www.linkedin.com/pulse/top-5-frameworks-building-ai-agents-2025-sahil-malhotra-wmisc?utm_source=openai))
#
# - **AutoGen**: Developed by Microsoft, AutoGen specializes in orchestrating multiple AI agents to form autonomous, event-driven systems capable of handling complex, multi-agent tasks seamlessly. It supports multi-agent orchestration and runtime convergence for scalable applications, making it ideal for enterprise-level systems. ([linkedin.com](https://www.linkedin.com/pulse/ai-agent-frameworks-june-2025-comprehensive-overview-chadi-abi-fadel-wcu5c?utm_source=openai))
#
# - **SuperAGI**: A production-grade, open-source agent framework designed for autonomy, SuperAGI includes scheduling, execution monitoring, performance dashboards, and persistent agent memory. It is suitable for building autonomous agents that require robust monitoring and management capabilities. ([medium.com](https://medium.com/%40rajadityasatellite/2025-is-the-year-of-ai-agent-frameworks-cb24e3f9ffc7?utm_source=openai))
#
# - **Eliza**: A Web3-friendly AI agent operating system, Eliza integrates seamlessly with web3 applications, allowing AI agents to interact with blockchain data and smart contracts. It emphasizes user control and stability in performance. ([arxiv.org](https://arxiv.org/abs/2501.06781?utm_source=openai))
#
# - **Agent Lightning**: A flexible and extensible framework that enables reinforcement learning-based training of large language models for any AI agent. It decouples agent execution from training, allowing seamless integration with existing agents developed via diverse methods. ([arxiv.org](https://arxiv.org/abs/2508.03680?utm_source=openai))
#
# - **AutoAgent**: A fully-automated and zero-code framework for LLM agents, AutoAgent enables users to create and deploy LLM agents through natural language alone. It serves as a versatile multi-agent system for general AI assistants. ([arxiv.org](https://arxiv.org/abs/2502.05957?utm_source=openai))
#
# These frameworks cater to various needs, from complex multi-agent systems to user-friendly, code-free development environments, reflecting the diverse advancements in AI agent technology in 2025.

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ### We will now use Structured Outputs, and include a description of the fields

# %%
# See note above about cost of WebSearchTool

HOW_MANY_SEARCHES = 3

INSTRUCTIONS = f"You are a helpful research assistant. Given a query, come up with a set of web searches \
to perform to best answer the query. Output {HOW_MANY_SEARCHES} terms to query for."

# Use Pydantic to define the Schema of our response - this is known as "Structured Outputs"
# With massive thanks to student Wes C. for discovering and fixing a nasty bug with this!

class WebSearchItem(BaseModel):
    reason: str = Field(description="Your reasoning for why this search is important to the query.")

    query: str = Field(description="The search term to use for the web search.")


class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem] = Field(description="A list of web searches to perform to best answer the query.")


planner_agent = Agent(
    name="PlannerAgent",
    instructions=INSTRUCTIONS,
    model="gpt-4o-mini",
    output_type=WebSearchPlan,
)

# %%
message = "Latest AI Agent frameworks in 2025"

with trace("Search"):
    result = await Runner.run(planner_agent, message)
    print(result.final_output)
# Out:
# searches=[WebSearchItem(reason='To find information on the most recent AI agent frameworks developed or popularized in 2025.', query='latest AI agent frameworks 2025'), WebSearchItem(reason='To gather insights on emerging trends and technologies in AI agent frameworks for 2025.', query='trends in AI agent frameworks 2025'), WebSearchItem(reason='To identify key players and tools in the AI agent space that have been released or updated in 2025.', query='AI agent frameworks tools 2025')]

# %%
for search in result.final_output.searches:
        print(f"reason: {search.reason}")
        print(f"query: {search.query}")
        print("-" * 50)
# Out:
# reason: To find information on the most recent AI agent frameworks developed or popularized in 2025.
# query: latest AI agent frameworks 2025
# --------------------------------------------------
# reason: To gather insights on emerging trends and technologies in AI agent frameworks for 2025.
# query: trends in AI agent frameworks 2025
# --------------------------------------------------
# reason: To identify key players and tools in the AI agent space that have been released or updated in 2025.
# query: AI agent frameworks tools 2025
# --------------------------------------------------

# %%
@function_tool
def send_email(subject: str, html_body: str) -> Dict[str, str]:
    """ Send out an email with the given subject and HTML body """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("vagnermachado84@gmail.com") # Change this to your verified email
    to_email = To("vagnermachado84@hotmail.com") # Change this to your email
    content = Content("text/html", html_body)
    mail = Mail(from_email, to_email, subject, content).get()
    response = sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %%
send_email

# %%
INSTRUCTIONS = """You are able to send a nicely formatted HTML email based on a detailed report.
You will be provided with a detailed report. You should use your tool to send one email, providing the 
report converted into clean, well presented HTML with an appropriate subject line."""

email_agent = Agent(
    name="Email agent",
    instructions=INSTRUCTIONS,
    tools=[send_email],
    model="gpt-4o-mini",
)

# %%
INSTRUCTIONS = (
    "You are a senior researcher tasked with writing a cohesive report for a research query. "
    "You will be provided with the original query, and some initial research done by a research assistant.\n"
    "You should first come up with an outline for the report that describes the structure and "
    "flow of the report. Then, generate the report and return that as your final output.\n"
    "The final output should be in markdown format, and it should be lengthy and detailed. Aim "
    "for 5-10 pages of content, at least 1000 words."
)


class ReportData(BaseModel):
    short_summary: str = Field(description="A short 2-3 sentence summary of the findings.")

    markdown_report: str = Field(description="The final report")

    follow_up_questions: list[str] = Field(description="Suggested topics to research further")


writer_agent = Agent(
    name="WriterAgent",
    instructions=INSTRUCTIONS,
    model="gpt-4o-mini",
    output_type=ReportData,
)

# %% [markdown]
# ### The next 3 functions will plan and execute the search, using planner_agent and search_agent

# %%
async def plan_searches(query: str):
    """ Use the planner_agent to plan which searches to run for the query """
    print("Planning searches...")
    result = await Runner.run(planner_agent, f"Query: {query}")
    print(f"Will perform {len(result.final_output.searches)} searches")
    return result.final_output

async def perform_searches(search_plan: WebSearchPlan):
    """ Call search() for each item in the search plan """
    print("Searching...")
    tasks = [asyncio.create_task(search(item)) for item in search_plan.searches]
    results = await asyncio.gather(*tasks)
    print("Finished searching")
    return results

async def search(item: WebSearchItem):
    """ Use the search agent to run a web search for each item in the search plan """
    input = f"Search term: {item.query}\nReason for searching: {item.reason}"
    result = await Runner.run(search_agent, input)
    return result.final_output

# %% [markdown]
# ### The next 2 functions write a report and email it

# %%
async def write_report(query: str, search_results: list[str]):
    """ Use the writer agent to write a report based on the search results"""
    print("Thinking about report...")
    input = f"Original query: {query}\nSummarized search results: {search_results}"
    result = await Runner.run(writer_agent, input)
    print("Finished writing report")
    return result.final_output

async def send_email(report: ReportData):
    """ Use the email agent to send an email with the report """
    print("Writing email...")
    result = await Runner.run(email_agent, report.markdown_report)
    print("Email sent")
    return report

# %% [markdown]
# ### Showtime!

# %%
query ="Latest AI Agent frameworks in 2025"

with trace("Research trace"):
    print("Starting research...")
    search_plan = await plan_searches(query)
    search_results = await perform_searches(search_plan)
    report = await write_report(query, search_results)
    await send_email(report)  
    print("Hooray!")
# Out:
# Starting research...
# Planning searches...
# Will perform 3 searches
# Searching...
# Finished searching
# Thinking about report...
# Finished writing report
# Writing email...
# Email sent
# Hooray!

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thanks.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00cc00;">Congratulations on your progress, and a request</h2>
#             <span style="color:#00cc00;">You've reached an important moment with the course; you've created a valuable Agent using one of the latest Agent frameworks. You've upskilled, and unlocked new commercial possibilities. Take a moment to celebrate your success!<br/><br/>Something I should ask you -- my editor would smack me if I didn't mention this. If you're able to rate the course on Udemy, I'd be seriously grateful: it's the most important way that Udemy decides whether to show the course to others and it makes a massive difference.<br/><br/>And another reminder to <a href="https://www.linkedin.com/in/eddonner/">connect with me on LinkedIn</a> if you wish! If you wanted to post about your progress on the course, please tag me and I'll weigh in to increase your exposure.
#             </span>
#         </td>
#     </tr>
